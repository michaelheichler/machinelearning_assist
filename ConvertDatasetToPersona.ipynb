# %% [markdown]
# # Import required Modules

# %%
import torch
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re

from typing import Dict, Any, Callable, List, Tuple, Optional, Union
from sklearn import metrics
from sklearn.utils.multiclass import unique_labels
from sklearn.base import BaseEstimator, TransformerMixin

# %%
from transformers import BertModel, BertTokenizer, DistilBertModel, DistilBertTokenizer
from transformers import (AdamW, OpenAIGPTDoubleHeadsModel, OpenAIGPTTokenizer)

# %%
tokenizer_class = OpenAIGPTTokenizer
tokenizer = tokenizer_class.from_pretrained("openai-gpt")

# %% [markdown]
# # Convert DF to CONVERSATION Dictonary

# %%
def convert_df_to_conv_ai_dict(df: pd.DataFrame,
                               personality: List[str],
                               response_columns: List[str],
                               tokenizer: Callable[[str], List[str]],
                               max_tokens: Optional[int] = None,
                               n_candidates: int = 6
                               ) -> Dict[str, List[Any]]:  
    # Add one because the index of the dataframe is the 0th position.
    tuple_map = {name: index + 1 for index, name in enumerate(df.columns.tolist())}
    train = []
    val = []
    # Step through every row in the dictionary
    for row in df.itertuples():
        question_text = row[tuple_map["body_1"]]
        for response_column in response_columns:
            candidates = sample_candidates(df, row[tuple_map["id"]], "id", "body", n_candidates)
            # questions = sample_candidates(df, row[tuple_map["id"]], "id", "body_1", n_candidates)
            if max_tokens is not None: 
                questions = tokenizer.convert_tokens_to_string(tokenizer.tokenize(question_text)[:max_tokens])
                candidates = [tokenizer.convert_tokens_to_string(tokenizer.tokenize(candidate)[:max_tokens]) for candidate in candidates]
                d = {"personality": personality,
                     "utterances": [{"history": questions,
                                     "candidates": candidates}]}
                if getattr(row, "split") == "train":
                    train.append(d)
                elif getattr(row, "split") == "val":
                    val.append(d)
                    
    data = {"train": train, "valid": val}
    
    return data

# %% [markdown]
# ### Candidate Sampling, see coment

# %%
def sample_candidates(df: pd.DataFrame, current_id: Any, id_column: Any, text_column: str, n: int) -> List[str]:
    """Samples candidate responses to a question from the dataframe

    It is aware of data splits and only samples from within the same split.  This avoids
    leaking information between training validation and testing.  The sampled responses are
    also drawn from all rows which do not have the same id as the current_id

    Args:
        df: The dataframe we want to sample responses from
        current_id: The unique identifier we would like to leave out of our sampling
        id_column: The column name in the dataframe with the unique ids.  current_id should
            be an element of this column
        text_column: The column with the text we want to sample
        n: How many samples we want to take.

    Returns:
        A list of samples strings from our dataframe.
    """
    # We must only sample candidates from the correct data split to avoid information leakage across channels
    split = df[df[id_column] == current_id]["split"].tolist()[0]
    candidate_df = df[df["split"] == split]

    # Sample 3 random rows from the dataframe not matching the current id
    sampled_texts = candidate_df[candidate_df[id_column] != current_id].sample(n + 15)[text_column].tolist()
    

    # join them all
    text = " ".join(sampled_texts)
    
    # Replace all newlines with spaces...
    text_no_newline = re.sub("\n", " ", text).lower()

    # Split on punctuation
    split_text = re.split('[?.!]', text_no_newline)

    # Remove all empty lines
    filtered_text = [x.strip() for x in split_text if len(x.strip()) > 1]

    # Shuffle the list
    return np.random.choice(filtered_text, n).tolist()

# %% [markdown]
# # Load Dataset

# %% [markdown]
# A dataset from Bigquery which includes a siterip from Stackoverflow. The column body inherits all answers of the questions which are shown in the column body_1

# %%
df = pd.read_csv("answers.csv", encoding='utf-8')

# %%
#a, b, c = np.split(df, [int(.2*len(df)), int(.5*len(df))])

# %%
n = 5
df_reduce = df.head(int(len(df)*(n/100)))

# %%
df_reduce = df_reduce.drop(['owner_user_id'], axis=1)

# %%
df = df_reduce

# %% [markdown]
# # Format Dataset

# %%
import string
import random

# %%
df["split"] = ""
df_1 = df.split.apply(lambda x: random.choice(['train', 'val']) ) 
df['split'] = df_1

# %% [markdown]
# # Convert Dataset

# %%
d = convert_df_to_conv_ai_dict(df, [""], ["body"], tokenizer, max_tokens=250, n_candidates=8)

# %%
import json

# %%
with open("tokens_stack.json", "w") as json_file:
    json.dump(d, json_file)

# %%
print(d)
# Out:
# {'train': [{'personality': [''], 'utterances': [{'history': 'i', 'candidates': ['1', '*']}]}, {'personality': [''], 'utterances': [{'history': 'i', 'candidates': ['on', 'out']}]}, {'personality': [''], 'utterances': [{'history': 'what', 'candidates': ['try', 'gather']}]}, {'personality': [''], 'utterances': [{'history': 'listed', 'candidates': ['*', 'there']}]}, {'personality': [''], 'utterances': [{'history': 'listed', 'candidates': ['you', 'otherwise']}]}, {'personality': [''], 'utterances': [{'history': 'i', 'candidates': ['r', 'org']}]}, {'personality': [''], 'utterances': [{'history': 'i', 'candidates': ['see', '21']}]}, {'personality': [''], 'utterances': [{'history': 'i', 'candidates': ['it', 'wiki']}]}, {'personality': [''], 'utterances': [{'history': 'the', 'candidates': ['actually', 'if']}]}, {'personality': [''], 'utterances': [{'history': 'i', 'candidates': ['org', 'com']}]}, {'personality': [''], 'utterances': [{'history': 'i', 'candidates': ['fron', '24']}]}, {'personality': [''], 'utterances': [{'history': 'i', 'candidates': ['0', '*']}]}, {'personality': [''], 'utterances': [{'history': 'using', 'candidates': ['18', 'you']}]}, {'personality': [''], 'utterances': [{'history': 'using', 'candidates': ['t', 'the']}]}, {'personality': [''], 'utterances': [{'history': 'i', 'candidates': ['_', '0']}]}, {'personality': [''], 'utterances': [{'history': 'i', 'candidates': ['\\', 'r']}]}, {'personality': [''], 'utterances': [{'history': 'i', 'candidates': ['i', 'con']}]}, {'personality': [''], 'utterances': [{'history': 'according', 'candidates': [';', '1']}]}, {'personality': [''], 'utterances': [{'history': 'i', 'candidates': ['micro', 'st']}]}, {'personality': [''], 'utterances': [{'history': 'i', 'candidates': ['modified', 'why']}]}, {'personality': [''], 'utterances': [{'history': 'i', 'candidates': ['you', 'this']}]}, {'personality': [''], 'utterances': [{'history': 'i', 'candidates': ['16', 'ht']}]}, {'personality': [''], 'utterances': [{'history': 'given', 'candidates': ['(', 'its']}]}, {'personality': [''], 'utterances': [{'history': 'given', 'candidates': ['net', ')']}]}, {'personality': [''], 'utterances': [{'history': 'given', 'candidates': ['ex', 'however']}]}, {'personality': [''], 'utterances': [{'history': 'if', 'candidates': ['com', 'speech']}]}, {'personality': [''], 'utterances': [{'history': 'trying', 'candidates': ['then', '6']}]}, {'personality': [''], 'utterances': [{'history': 'does', 'candidates': ['this', '=']}]}, {'personality': [''], 'utterances': [{'history': 'in', 'candidates': ['but', 'j']}]}, {'personality': [''], 'utterances': [{'history': 'i', 'candidates': ['pipe', '/']}]}, {'personality': [''], 'utterances': [{'history': 'the', 'candidates': ['the', '--']}]}, {'personality': [''], 'utterances': [{'history': 'the', 'candidates': ['the', 'just']}]}, {'personality': [''], 'utterances': [{'history': 'the', 'candidates': ['log', 'your']}]}, {'personality': [''], 'utterances': [{'history': 'the', 'candidates': ['h', '15']}]}, {'personality': [''], 'utterances': [{'history': 'instead', 'candidates': ['many', 'trailing']}]}, {'personality': [''], 'utterances': [{'history': 'my', 'candidates': ['in', 'otherwise']}]}, {'personality': [''], 'utterances': [{'history': 'i', 'candidates': ['eh', 'as']}]}, {'personality': [''], 'utterances': [{'history': 'i', 'candidates': ['as', 'any']}]}, {'personality': [''], 'utterances': [{'history': 'i', 'candidates': ['please', ')']}]}, {'personality': [''], 'utterances': [{'history': 'i', 'candidates': ['t', 'd']}]}, {'personality': [''], 'utterances': [{'history': 'i', 'candidates': ['i', 'js']}]}, {'personality': [''], 'utterances': [{'history': 'when', 'candidates': ['org', 'i']}]}, {'personality': [''], 'utterances': [{'history': 'is', 'candidates': ['here', 'i']}]}, {'personality': [''], 'utterances': [{'history': 'is', 'candidates': ['git', '0']}]}, {'personality': [''], 'utterances': [{'history': 'i', 'candidates': ['/', 'so']}]}, {'personality': [''],  ...
